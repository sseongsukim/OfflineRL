# %%
import jax
import jax.numpy as jnp
from jaxrl_m.networks import EnsembleDyanmics

rng = jax.random.PRNGKey(0)
rng, obsaction_key, model_key = jax.random.split(rng, 3)
num_ensemble = 7
obs_dim = 17
action_dim = 6
hidden_dims = [200, 200, 200, 200]
weight_decays = [2.5e-5, 5e-5, 7.5e-5, 7.5e-5, 1e-4]
obs_actions = jax.random.normal(obsaction_key, (7, 512, 23))
model = EnsembleDyanmics(
    obs_dim, action_dim, hidden_dims, weight_decays, num_ensemble, True
)
params = model.init(model_key, obs_actions)
params
# Out:
# {'params': {'min_logvar': Array([-10., -10., -10., -10., -10., -10., -10., -10., -10., -10., -10.,
#          -10., -10., -10., -10., -10., -10., -10.], dtype=float32),
#   'max_logvar': Array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#          0.5, 0.5, 0.5, 0.5, 0.5], dtype=float32),
#   'layers_0': {'kernel': Array([[[-1.2205116e-02,  2.0009454e-02, -8.4481016e-03, ...,
#             -9.9962289e-03, -5.2496484e-03, -2.9521082e-02],
#            [ 3.3197928e-02,  1.4189356e-02,  1.7829478e-02, ...,
#              3.4969419e-02, -7.9912469e-03,  2.6788686e-03],
#            [ 1.9528221e-02, -7.0224213e-03,  6.9623976e-03, ...,
#             -6.7902237e-02, -6.5915070e-02, -3.9027002e-02],
#            ...,
#            [ 1.8601321e-02,  1.7150337e-02, -2.2932695e-02, ...,
#             -3.2357447e-02, -4.3325745e-02,  6.2621236e-02],
#            [-1.4284524e-02, -5.2835189e-02,  1.4490713e-02, ...,
# ...

# %%
mean, logvar = model.apply(params, obs_actions)
# Out:
# {'params': {'min_logvar': Array([-10., -10., -10., -10., -10., -10., -10., -10., -10., -10., -10.,
#          -10., -10., -10., -10., -10., -10., -10.], dtype=float32),
#   'max_logvar': Array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#          0.5, 0.5, 0.5, 0.5, 0.5], dtype=float32),
#   'layers_0': {'kernel': Array([[[-1.2205116e-02,  2.0009454e-02, -8.4481016e-03, ...,
#             -9.9962289e-03, -5.2496484e-03, -2.9521082e-02],
#            [ 3.3197928e-02,  1.4189356e-02,  1.7829478e-02, ...,
#              3.4969419e-02, -7.9912469e-03,  2.6788686e-03],
#            [ 1.9528221e-02, -7.0224213e-03,  6.9623976e-03, ...,
#             -6.7902237e-02, -6.5915070e-02, -3.9027002e-02],
#            ...,
#            [ 1.8601321e-02,  1.7150337e-02, -2.2932695e-02, ...,
#             -3.2357447e-02, -4.3325745e-02,  6.2621236e-02],
#            [-1.4284524e-02, -5.2835189e-02,  1.4490713e-02, ...,
# ...

# %%
decay_loss
# Out:
# Array(0.02360144, dtype=float32)

# %%
mean.shape
# Out:
# (7, 512, 18)
